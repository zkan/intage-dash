# %% [markdown]
# # Typeform Data API Test

# %% [markdown]
# ทดสอบการใช้งาน Data API ของ Typeform

# %%
import os

# %%
form_id = 'iPMP4Y'
TYPEFORM_API_KEY = 'APIKEY'
url = 'https://api.typeform.com/v1/form/' + form_id + '?key=' + TYPEFORM_API_KEY

# %%
import requests

# %%
response = requests.get(url)
results = response.json()

# %%
questions = results.get('questions')
questions
# Out:
# [{'field_id': 53332714, 'id': 'list_53332714_choice', 'question': 'สาขา'},
#  {'field_id': 53329680,
#   'id': 'group_53329680',
#   'question': 'กรุณาบอกหน่อยว่าการบริการหลังการขายของตัวแทนจำหน่ายหรือศูนย์บริการของบริษัท มาย มอเตอร'},
#  {'field_id': 53329694,
#   'group': 'group_53329680',
#   'id': 'rating_53329694',
#   'question': 'การต้อนรับของพนักงาน เช่นเป็นกันเอง สุภาพ'},
#  {'field_id': 53329702,
#   'group': 'group_53329680',
#   'id': 'rating_53329702',
#   'question': 'ประสิทธิภาพในการซ่อม เช่น แก้ปัญหาได้ตรงจุดตั้งแต่การตรวจเช็คครั้งแรก'},
#  {'field_id': 53329705,
#   'group': 'group_53329680',
#   'id': 'rating_53329705',
#   'question': 'ความรู้และความสามารถของพนักงานในการแก้ไข และวิเคราะห์ปัญหา'},
#  {'field_id': 53329716,
#   'group': 'group_53329680',
#   'id': 'rating_53329716',
#   'question': 'ระยะเวลาที่ใช้ในการซ่อม'},
#  {'field_id': 53329717,
#   'group': 'group_53329680',
#   'id': 'rating_53329717',
#   'question': 'ราคาค่าซ่อมมีความเหมาะสม'},
#  {'field_id': 53330038,
#   'id': 'group_53330038',
#   'question': 'เมื่อพูดถึงประสบการณในการเข้าใช้ศูนย์บริการของบริษัท มาย มอเตอร์ (ประเทศไทย) จำกัดครั้งนี'},
#  {'field_id': 53175039,
#   'group': 'group_53330038',
#   'id': 'rating_53175039',
#   'question': 'สถานที่จอดรถลูกค้าเข้าใช้ศูนย์บริการ'},
#  {'field_id': 53175044,
#   'group': 'group_53330038',
#   'id': 'rating_53175044',
#   'question': 'พนักงานกล่าวสวัสดีเมื่อเข้าศูนย์บริการ'},
#  {'field_id': 53175043,
#   'group': 'group_53330038',
#   'id': 'rating_53175043',
#   'question': 'พนักงานสอบถามความต้องการใช้บริการ'},
#  {'field_id': 53175042,
#   'group': 'group_53330038',
#   'id': 'rating_53175042',
#   'question': 'มารยาทของพนักงาน'},
#  {'field_id': 53175041,
#   'group': 'group_53330038',
#   'id': 'rating_53175041',
#   'question': 'พนักงานมีความสุภาพ'},
#  {'field_id': 53175089,
#   'group': 'group_53330038',
#   'id': 'rating_53175089',
#   'question': 'พนักงานมีความเป็นกันเอง'},
#  {'field_id': 53330117,
#   'id': 'group_53330117',
#   'question': 'เมื่อพูดถึง\xa0ประสิทธิภาพในการซ่อม\xa0ของศูนย์บริการของบริษัท มาย มอเตอร์ (ประเทศไทย) จำกัดครั'},
#  {'field_id': 53175164,
#   'group': 'group_53330117',
#   'id': 'rating_53175164',
#   'question': 'พนักงานบริการอธิบายว่าได้ทำอะไรบ้าง ตามที่ระบุในใบงาน'},
#  {'field_id': 53175165,
#   'group': 'group_53330117',
#   'id': 'rating_53175165',
#   'question': 'พนักงานให้บริการครบถ้วนตามรายการสั่งซ่อม'},
#  {'field_id': 53175186,
#   'group': 'group_53330117',
#   'id': 'rating_53175186',
#   'question': 'แก้ปัญหาได้ตรงจุดตั้งแต่การตรวจเช็คครั้งแรก'},
#  {'field_id': 53330290,
#   'id': 'group_53330290',
#   'question': 'เมื่อพูดถึง\xa0ความรู้และความสามารถของพนักงานในการแก้ไข และวิเคราะห์ปัญหา\xa0ของศูนย์บริการข'},
#  {'field_id': 53175203,
#   'group': 'group_53330290',
#   'id': 'rating_53175203',
#   'question': 'รับฟังอย่างตั้งใจและจดรายละเอียดเกี่ยวกับสิ่งที่คุณเอ่ย'},
#  {'field_id': 53175209,
#   'group': 'group_53330290',
#   'id': 'rating_53175209',
#   'question': 'ตอบข้อซักถามและให้ข้อมูลได้อย่างมีประสิทธิภาพ ทันท่วงที'},
#  {'field_id': 53175237,
#   'group': 'group_53330290',
#   'id': 'rating_53175237',
#   'question': 'พนักงานบริการได้มีการชี้แจงรายการซ่อม และอธิบายรายละเอียดให้คุณทราบ'},
#  {'field_id': 53175244,
#   'group': 'group_53330290',
#   'id': 'rating_53175244',
#   'question': 'พนักงานบริการได้อธิบายการดูแลรักษารถเบื้องต้นที่เป็นประโยชน์'},
#  {'field_id': 53330322,
#   'id': 'group_53330322',
#   'question': 'เมื่อพูดถึง\xa0ระยะเวลาที่ใช้ในการซ่อม\xa0ของศูนย์บริการของบริษัท มาย มอเตอร์ (ประเทศไทย) จำกัด'},
#  {'field_id': 53175274,
#   'group': 'group_53330322',
#   'id': 'rating_53175274',
#   'question': 'การประเมินเวลาที่ใช้ในการซ่อมแล้วเสร็จ'},
#  {'field_id': 53175291,
#   'group': 'group_53330322',
#   'id': 'rating_53175291',
#   'question': 'พนักงานบริการได้ติดต่อคุณในระหว่างวัน หรือได้รับการแจ้งในระหว่างที่คุณรอรถซ่อม'},
#  {'field_id': 53175406,
#   'group': 'group_53330322',
#   'id': 'rating_53175406',
#   'question': 'พนักงานบริการซ่อมรถเสร็จตามเวลานัดหมาย'},
#  {'field_id': 53175427,
#   'group': 'group_53330322',
#   'id': 'rating_53175427',
#   'question': 'ระยะเวลาที่ใช้ในการซ่อมหรือรับบริการ'},
#  {'field_id': 53330394,
#   'id': 'group_53330394',
#   'question': 'เมื่อพูดถึง\xa0การเข้าถึงช่องทางการแจ้งซ่อม\xa0ของศูนย์บริการของบริษัท มาย มอเตอร์ (ประเทศไทย) '},
#  {'field_id': 53175466,
#   'group': 'group_53330394',
#   'id': 'rating_53175466',
#   'question': 'ช่องทางการแจ้งซ่อมสะดวกและง่าย'},
#  {'field_id': 53175489,
#   'group': 'group_53330394',
#   'id': 'rating_53175489',
#   'question': 'การสอบถามเพื่อเสนอความช่วยเหลือในการเข้ารับบริการ'},
#  {'field_id': 53330407,
#   'id': 'group_53330407',
#   'question': 'เมื่อพูดถึง\xa0ราคาค่าซ่อม\xa0ของศูนย์บริการของบริษัท มาย มอเตอร์ (ประเทศไทย) จำกัดครั้งนี้ คุณม'},
#  {'field_id': 53175570,
#   'group': 'group_53330407',
#   'id': 'rating_53175570',
#   'question': 'การแจ้งประเมินราคาค่าซ่อมล่วงหน้าชัดเจน'},
#  {'field_id': 53175574,
#   'group': 'group_53330407',
#   'id': 'rating_53175574',
#   'question': 'การบริการของพนักงานเก็บเงิน'},
#  {'field_id': 53175588,
#   'group': 'group_53330407',
#   'id': 'rating_53175588',
#   'question': 'ความสุภาพของพนักงานเก็บเงิน'},
#  {'field_id': 53175592,
#   'group': 'group_53330407',
#   'id': 'rating_53175592',
#   'question': 'ขั้นตอนการชำระเงินเป็นไปอย่างรวดเร็วและเป็นมืออาชีพ'},
#  {'field_id': 53175596,
#   'group': 'group_53330407',
#   'id': 'rating_53175596',
#   'question': 'ราคาค่าซ่อมมีความเหมาะสม'}]

# %%
responses = results.get('responses')
responses
# Out:
# [{'answers': {},
#   'completed': '0',
#   'hidden': [],
#   'metadata': {'browser': 'default',
#    'date_land': '2017-06-10 06:48:04',
#    'date_submit': '0000-00-00 00:00:00',
#    'network_id': 'c24e0c0578',
#    'platform': 'other',
#    'referer': 'https://outing1.typeform.com/to/iPMP4Y',
#    'user_agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36'},
#   'token': '96bf52e95bc0566b9a94fd988c748473'},
#  {'answers': {},
#   'completed': '0',
#   'hidden': [],
#   'metadata': {'browser': 'default',
#    'date_land': '2017-06-10 06:56:35',
#    'date_submit': '0000-00-00 00:00:00',
#    'network_id': 'c24e0c0578',
#    'platform': 'other',
#    'referer': 'https://outing1.typeform.com/to/iPMP4Y',
#    'user_agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36'},
#   'token': '927c27a242d801a6bc42a44e0f86852b'},
#  {'answers': {},
#   'completed': '0',
#   'hidden': [],
#   'metadata': {'browser': 'touch',
#    'date_land': '2017-06-10 08:45:28',
#    'date_submit': '0000-00-00 00:00:00',
#    'network_id': 'fd1aa83c29',
#    'platform': 'mobile',
#    'referer': 'https://outing1.typeform.com/to/iPMP4Y',
#    'user_agent': 'Mozilla/5.0 (Linux; Android 7.0; SM-N920C Build/NRD90M; wv) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/58.0.3029.83 Mobile Safari/537.36 Line/7.5.2/IAB'},
#   'token': 'ac14558e658bab4ce73cc0c4862c5314'},
#  {'answers': {},
#   'completed': '0',
#   'hidden': [],
#   'metadata': {'browser': 'touch',
#    'date_land': '2017-06-10 10:09:56',
#    'date_submit': '0000-00-00 00:00:00',
#    'network_id': '5b10e34139',
#    'platform': 'mobile',
#    'referer': 'https://outing1.typeform.com/to/iPMP4Y',
#    'user_agent': 'Mozilla/5.0 (iPhone; CPU iPhone OS 10_3_2 like Mac OS X) AppleWebKit/603.2.4 (KHTML, like Gecko) Mobile/14F89 Safari Line/7.5.1'},
#   'token': 'f34eb34655f93e74192b252b5e033a45'},
#  {'answers': {},
#   'completed': '0',
#   'hidden': [],
#   'metadata': {'browser': 'default',
#    'date_land': '2017-06-12 10:42:38',
#    'date_submit': '0000-00-00 00:00:00',
#    'network_id': 'c24e0c0578',
#    'platform': 'other',
#    'referer': 'https://outing1.typeform.com/to/iPMP4Y',
#    'user_agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36'},
#   'token': '7e24a332f56cd261fed79cd9549556b3'},
#  {'answers': {},
#   'completed': '0',
#   'hidden': [],
#   'metadata': {'browser': 'default',
#    'date_land': '2017-06-12 13:07:28',
#    'date_submit': '0000-00-00 00:00:00',
#    'network_id': '1370b9c56d',
#    'platform': 'other',
#    'referer': 'https://outing1.typeform.com/to/iPMP4Y',
#    'user_agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36'},
#   'token': '692a3fdd4c5eaf3568621178fd1a79ad'},
#  {'answers': {},
#   'completed': '0',
#   'hidden': [],
#   'metadata': {'browser': 'default',
#    'date_land': '2017-06-12 13:21:04',
#    'date_submit': '0000-00-00 00:00:00',
#    'network_id': '1370b9c56d',
#    'platform': 'other',
#    'referer': 'https://outing1.typeform.com/to/iPMP4Y',
#    'user_agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36'},
#   'token': 'c3eb1b840f7cb702f73af69f2b7311df'},
#  {'answers': {},
#   'completed': '0',
#   'hidden': [],
#   'metadata': {'browser': 'default',
#    'date_land': '2017-06-12 13:39:00',
#    'date_submit': '0000-00-00 00:00:00',
#    'network_id': '1370b9c56d',
#    'platform': 'other',
#    'referer': 'https://outing1.typeform.com/to/iPMP4Y',
#    'user_agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36'},
#   'token': 'ef4fc3ea0d806ef26bf72d0b98d671e8'},
#  {'answers': {},
#   'completed': '0',
#   'hidden': [],
#   'metadata': {'browser': 'default',
#    'date_land': '2017-06-12 23:18:23',
#    'date_submit': '0000-00-00 00:00:00',
#    'network_id': '42041830ec',
#    'platform': 'other',
#    'referer': 'https://outing1.typeform.com/to/iPMP4Y',
#    'user_agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36'},
#   'token': '5eebf9dc9e5a94958e5c1b0b4aa88149'},
#  {'answers': {},
#   'completed': '0',
#   'hidden': [],
#   'metadata': {'browser': 'default',
#    'date_land': '2017-06-12 23:32:02',
#    'date_submit': '0000-00-00 00:00:00',
#    'network_id': '42041830ec',
#    'platform': 'other',
#    'referer': 'https://outing1.typeform.com/to/iPMP4Y',
#    'user_agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36'},
#   'token': '9b28e30ffb9d8e1dafbf632e274e736a'},
#  {'answers': {'list_53332714_choice': 'สาขา 2',
#    'rating_53175039': '3',
#    'rating_53175041': '3',
#    'rating_53175042': '2',
#    'rating_53175043': '3',
#    'rating_53175044': '4',
#    'rating_53175089': '4',
#    'rating_53175164': '5',
#    'rating_53175165': '1',
#    'rating_53175186': '2',
#    'rating_53175203': '3',
#    'rating_53175209': '4',
#    'rating_53175237': '3',
#    'rating_53175244': '4',
#    'rating_53175274': '2',
#    'rating_53175291': '5',
#    'rating_53175406': '1',
#    'rating_53175427': '2',
#    'rating_53175466': '4',
#    'rating_53175489': '3',
#    'rating_53175570': '2',
#    'rating_53175574': '4',
#    'rating_53175588': '2',
#    'rating_53175592': '4',
#    'rating_53175596': '1',
#    'rating_53329694': '4',
#    'rating_53329702': '8',
#    'rating_53329705': '5',
#    'rating_53329716': '9',
#    'rating_53329717': '6'},
#   'completed': '1',
#   'hidden': [],
#   'metadata': {'browser': 'default',
#    'date_land': '2017-06-13 00:22:59',
#    'date_submit': '2017-06-13 00:23:49',
#    'network_id': '42041830ec',
#    'platform': 'other',
#    'referer': 'https://outing1.typeform.com/to/iPMP4Y',
#    'user_agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36'},
#   'token': '39e0cb82278592b516c774c340e9ff48'},
#  {'answers': {'list_53332714_choice': 'สาขา 2',
#    'rating_53175039': '4',
#    'rating_53175041': '2',
#    'rating_53175042': '5',
#    'rating_53175043': '4',
#    'rating_53175044': '3',
#    'rating_53175089': '2',
#    'rating_53175164': '1',
#    'rating_53175165': '3',
#    'rating_53175186': '4',
#    'rating_53175203': '5',
#    'rating_53175209': '1',
#    'rating_53175237': '2',
#    'rating_53175244': '3',
#    'rating_53175274': '5',
#    'rating_53175291': '2',
#    'rating_53175406': '4',
#    'rating_53175427': '1',
#    'rating_53175466': '5',
#    'rating_53175489': '1',
#    'rating_53175570': '2',
#    'rating_53175574': '4',
#    'rating_53175588': '2',
#    'rating_53175592': '1',
#    'rating_53175596': '4',
#    'rating_53329694': '4',
#    'rating_53329702': '5',
#    'rating_53329705': '7',
#    'rating_53329716': '2',
#    'rating_53329717': '3'},
#   'completed': '1',
#   'hidden': [],
#   'metadata': {'browser': 'default',
#    'date_land': '2017-06-13 00:34:10',
#    'date_submit': '2017-06-13 00:34:56',
#    'network_id': '42041830ec',
#    'platform': 'other',
#    'referer': 'https://outing1.typeform.com/to/iPMP4Y',
#    'user_agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36'},
#   'token': '8b76eca019bba565e9d302d6ccfff6dc'},
#  {'answers': {'list_53332714_choice': 'สาขา 1',
#    'rating_53175039': '5',
#    'rating_53175041': '2',
#    'rating_53175042': '3',
#    'rating_53175043': '2',
#    'rating_53175044': '5',
#    'rating_53175089': '4',
#    'rating_53175164': '5',
#    'rating_53175165': '2',
#    'rating_53175186': '4',
#    'rating_53175203': '2',
#    'rating_53175209': '3',
#    'rating_53175237': '5',
#    'rating_53175244': '1',
#    'rating_53175274': '2',
#    'rating_53175291': '2',
#    'rating_53175406': '3',
#    'rating_53175427': '3',
#    'rating_53175466': '4',
#    'rating_53175489': '5',
#    'rating_53175570': '2',
#    'rating_53175574': '3',
#    'rating_53175588': '3',
#    'rating_53175592': '4',
#    'rating_53175596': '2',
#    'rating_53329694': '7',
#    'rating_53329702': '8',
#    'rating_53329705': '2',
#    'rating_53329716': '4',
#    'rating_53329717': '9'},
#   'completed': '1',
#   'hidden': [],
#   'metadata': {'browser': 'default',
#    'date_land': '2017-06-13 00:35:38',
#    'date_submit': '2017-06-13 00:36:18',
#    'network_id': '42041830ec',
#    'platform': 'other',
#    'referer': 'https://outing1.typeform.com/to/iPMP4Y',
#    'user_agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36'},
#   'token': 'f8677992b2853ae3e782bcb1288e10eb'},
#  {'answers': {},
#   'completed': '0',
#   'hidden': [],
#   'metadata': {'browser': 'default',
#    'date_land': '2017-06-13 02:21:52',
#    'date_submit': '0000-00-00 00:00:00',
#    'network_id': '42041830ec',
#    'platform': 'other',
#    'referer': 'https://outing1.typeform.com/to/iPMP4Y',
#    'user_agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36'},
#   'token': '83920bf065d8540fd9ce23fd034118b1'},
#  {'answers': {'list_53332714_choice': 'สาขา 1',
#    'rating_53175039': '4',
#    'rating_53175041': '3',
#    'rating_53175042': '3',
#    'rating_53175043': '4',
#    'rating_53175044': '2',
#    'rating_53175089': '5',
#    'rating_53175164': '5',
#    'rating_53175165': '5',
#    'rating_53175186': '5',
#    'rating_53175203': '5',
#    'rating_53175209': '4',
#    'rating_53175237': '4',
#    'rating_53175244': '4',
#    'rating_53175274': '4',
#    'rating_53175291': '4',
#    'rating_53175406': '4',
#    'rating_53175427': '4',
#    'rating_53175466': '4',
#    'rating_53175489': '4',
#    'rating_53175570': '4',
#    'rating_53175574': '4',
#    'rating_53175588': '4',
#    'rating_53175592': '4',
#    'rating_53175596': '4',
#    'rating_53329694': '7',
#    'rating_53329702': '7',
#    'rating_53329705': '7',
#    'rating_53329716': '7',
#    'rating_53329717': '7'},
#   'completed': '1',
#   'hidden': [],
#   'metadata': {'browser': 'default',
#    'date_land': '2017-06-13 02:22:12',
#    'date_submit': '2017-06-13 02:24:14',
#    'network_id': '42041830ec',
#    'platform': 'other',
#    'referer': 'https://outing1.typeform.com/to/iPMP4Y',
#    'user_agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36'},
#   'token': '7985fee795ae7bb935fc657da4706255'}]

# %%
print('Total Responses: ' + str(len(responses)))
# Out:
# Total Responses: 15

# %% [markdown]
# เปลี่ยน rating ให้กลายเป็น integer เนื่องจากตอนที่ดึงข้อมูลจาก API ข้อมูลส่วนของ rating จะมาเป็น string

# %%
answers = [each['answers'] for each in responses]
for answer in answers:
    for each in answer:
        if 'rating_' in each:
            answer[each] = int(answer[each])

# %% [markdown]
# แสดงคำตอบของแต่ละคนเพื่อเช็คว่าค่า rating ที่ได้มาเป็น integer แล้ว

# %%
print(answers)
# Out:
# [{}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {'rating_53175237': 3, 'rating_53175592': 4, 'rating_53175489': 3, 'list_53332714_choice': 'สาขา 2', 'rating_53329694': 4, 'rating_53175244': 4, 'rating_53329716': 9, 'rating_53175274': 2, 'rating_53175039': 3, 'rating_53175574': 4, 'rating_53175570': 2, 'rating_53175291': 5, 'rating_53175209': 4, 'rating_53175406': 1, 'rating_53175089': 4, 'rating_53175596': 1, 'rating_53329717': 6, 'rating_53175044': 4, 'rating_53175203': 3, 'rating_53329705': 5, 'rating_53175165': 1, 'rating_53175588': 2, 'rating_53329702': 8, 'rating_53175042': 2, 'rating_53175041': 3, 'rating_53175466': 4, 'rating_53175043': 3, 'rating_53175427': 2, 'rating_53175164': 5, 'rating_53175186': 2}, {'rating_53175237': 2, 'rating_53175592': 1, 'rating_53175489': 1, 'list_53332714_choice': 'สาขา 2', 'rating_53329694': 4, 'rating_53175244': 3, 'rating_53329716': 2, 'rating_53175274': 5, 'rating_53175039': 4, 'rating_53175574': 4, 'rating_53175570': 2, 'rating_53175291': 2, 'rating_53175209': 1, 'rating_53175406': 4, 'rating_53175089': 2, 'rating_53175596': 4, 'rating_53329717': 3, 'rating_53175044': 3, 'rating_53175203': 5, 'rating_53329705': 7, 'rating_53175165': 3, 'rating_53175588': 2, 'rating_53329702': 5, 'rating_53175042': 5, 'rating_53175041': 2, 'rating_53175466': 5, 'rating_53175043': 4, 'rating_53175427': 1, 'rating_53175164': 1, 'rating_53175186': 4}, {'rating_53175237': 5, 'rating_53175592': 4, 'rating_53175489': 5, 'list_53332714_choice': 'สาขา 1', 'rating_53329694': 7, 'rating_53175244': 1, 'rating_53329716': 4, 'rating_53175274': 2, 'rating_53175039': 5, 'rating_53175574': 3, 'rating_53175570': 2, 'rating_53175291': 2, 'rating_53175209': 3, 'rating_53175406': 3, 'rating_53175089': 4, 'rating_53175596': 2, 'rating_53329717': 9, 'rating_53175044': 5, 'rating_53175203': 2, 'rating_53329705': 2, 'rating_53175165': 2, 'rating_53175588': 3, 'rating_53329702': 8, 'rating_53175042': 3, 'rating_53175041': 2, 'rating_53175466': 4, 'rating_53175043': 2, 'rating_53175427': 3, 'rating_53175164': 5, 'rating_53175186': 4}, {}, {'rating_53175237': 4, 'rating_53175592': 4, 'rating_53175489': 4, 'list_53332714_choice': 'สาขา 1', 'rating_53329694': 7, 'rating_53175244': 4, 'rating_53329716': 7, 'rating_53175274': 4, 'rating_53175039': 4, 'rating_53175574': 4, 'rating_53175570': 4, 'rating_53175291': 4, 'rating_53175209': 4, 'rating_53175406': 4, 'rating_53175089': 5, 'rating_53175596': 4, 'rating_53329717': 7, 'rating_53175044': 2, 'rating_53175203': 5, 'rating_53329705': 7, 'rating_53175165': 5, 'rating_53175588': 4, 'rating_53329702': 7, 'rating_53175042': 3, 'rating_53175041': 3, 'rating_53175466': 4, 'rating_53175043': 4, 'rating_53175427': 4, 'rating_53175164': 5, 'rating_53175186': 5}]

# %%
print('Completion rate: ' + str(len(list(filter(lambda x: x, answers))) / len(answers)))
# Out:
# Completion rate: 0.26666666666666666

# %% [markdown]
# ### ใช้ Pandas เข้ามาช่วยจัดการข้อมูล

# %%
import pandas as pd

# %%
df = pd.DataFrame(answers)

# %%
df[df['list_53332714_choice'] == 'สาขา 2']
# Out:
#    list_53332714_choice  rating_53175039  rating_53175041  rating_53175042  \
# 10               สาขา 2              3.0              3.0              2.0
# 11               สาขา 2              4.0              2.0              5.0
#
#     rating_53175043  rating_53175044  rating_53175089  rating_53175164  \
# 10              3.0              4.0              4.0              5.0
# 11              4.0              3.0              2.0              1.0
#
#     rating_53175165  rating_53175186       ...         rating_53175570  \
# 10              1.0              2.0       ...                     2.0
# 11              3.0              4.0       ...                     2.0
#
#     rating_53175574  rating_53175588  rating_53175592  rating_53175596  \
# 10              4.0              2.0              4.0              1.0
# 11              4.0              2.0              1.0              4.0
#
#     rating_53329694  rating_53329702  rating_53329705  rating_53329716  \
# 10              4.0              8.0              5.0              9.0
# 11              4.0              5.0              7.0              2.0
#
#     rating_53329717
# 10              6.0
# 11              3.0
#
# [2 rows x 30 columns]

# %%
df[df['list_53332714_choice'] == 'สาขา 1']
# Out:
#    list_53332714_choice  rating_53175039  rating_53175041  rating_53175042  \
# 12               สาขา 1              5.0              2.0              3.0
# 14               สาขา 1              4.0              3.0              3.0
#
#     rating_53175043  rating_53175044  rating_53175089  rating_53175164  \
# 12              2.0              5.0              4.0              5.0
# 14              4.0              2.0              5.0              5.0
#
#     rating_53175165  rating_53175186       ...         rating_53175570  \
# 12              2.0              4.0       ...                     2.0
# 14              5.0              5.0       ...                     4.0
#
#     rating_53175574  rating_53175588  rating_53175592  rating_53175596  \
# 12              3.0              3.0              4.0              2.0
# 14              4.0              4.0              4.0              4.0
#
#     rating_53329694  rating_53329702  rating_53329705  rating_53329716  \
# 12              7.0              8.0              2.0              4.0
# 14              7.0              7.0              7.0              7.0
#
#     rating_53329717
# 12              9.0
# 14              7.0
#
# [2 rows x 30 columns]

# %%
df_questions = pd.DataFrame(questions)
df_questions
# Out:
#     field_id           group                    id  \
# 0   53332714             NaN  list_53332714_choice
# 1   53329680             NaN        group_53329680
# 2   53329694  group_53329680       rating_53329694
# 3   53329702  group_53329680       rating_53329702
# 4   53329705  group_53329680       rating_53329705
# 5   53329716  group_53329680       rating_53329716
# 6   53329717  group_53329680       rating_53329717
# 7   53330038             NaN        group_53330038
# 8   53175039  group_53330038       rating_53175039
# 9   53175044  group_53330038       rating_53175044
# 10  53175043  group_53330038       rating_53175043
# 11  53175042  group_53330038       rating_53175042
# 12  53175041  group_53330038       rating_53175041
# 13  53175089  group_53330038       rating_53175089
# 14  53330117             NaN        group_53330117
# 15  53175164  group_53330117       rating_53175164
# 16  53175165  group_53330117       rating_53175165
# 17  53175186  group_53330117       rating_53175186
# 18  53330290             NaN        group_53330290
# 19  53175203  group_53330290       rating_53175203
# 20  53175209  group_53330290       rating_53175209
# 21  53175237  group_53330290       rating_53175237
# 22  53175244  group_53330290       rating_53175244
# 23  53330322             NaN        group_53330322
# 24  53175274  group_53330322       rating_53175274
# 25  53175291  group_53330322       rating_53175291
# 26  53175406  group_53330322       rating_53175406
# 27  53175427  group_53330322       rating_53175427
# 28  53330394             NaN        group_53330394
# 29  53175466  group_53330394       rating_53175466
# 30  53175489  group_53330394       rating_53175489
# 31  53330407             NaN        group_53330407
# 32  53175570  group_53330407       rating_53175570
# 33  53175574  group_53330407       rating_53175574
# 34  53175588  group_53330407       rating_53175588
# 35  53175592  group_53330407       rating_53175592
# 36  53175596  group_53330407       rating_53175596
#
#                                              question
# 0                                                สาขา
# 1   กรุณาบอกหน่อยว่าการบริการหลังการขายของตัวแทนจำ...
# 2           การต้อนรับของพนักงาน เช่นเป็นกันเอง สุภาพ
# 3   ประสิทธิภาพในการซ่อม เช่น แก้ปัญหาได้ตรงจุดตั้...
# 4   ความรู้และความสามารถของพนักงานในการแก้ไข และวิ...
# 5                             ระยะเวลาที่ใช้ในการซ่อม
# 6                            ราคาค่าซ่อมมีความเหมาะสม
# 7   เมื่อพูดถึงประสบการณในการเข้าใช้ศูนย์บริการของ...
# 8                สถานที่จอดรถลูกค้าเข้าใช้ศูนย์บริการ
# 9              พนักงานกล่าวสวัสดีเมื่อเข้าศูนย์บริการ
# 10                  พนักงานสอบถามความต้องการใช้บริการ
# 11                                   มารยาทของพนักงาน
# 12                                 พนักงานมีความสุภาพ
# 13                            พนักงานมีความเป็นกันเอง
# 14  เมื่อพูดถึง ประสิทธิภาพในการซ่อม ของศูนย์บริกา...
# 15  พนักงานบริการอธิบายว่าได้ทำอะไรบ้าง ตามที่ระบุ...
# 16           พนักงานให้บริการครบถ้วนตามรายการสั่งซ่อม
# 17        แก้ปัญหาได้ตรงจุดตั้งแต่การตรวจเช็คครั้งแรก
# 18  เมื่อพูดถึง ความรู้และความสามารถของพนักงานในกา...
# 19  รับฟังอย่างตั้งใจและจดรายละเอียดเกี่ยวกับสิ่งท...
# 20  ตอบข้อซักถามและให้ข้อมูลได้อย่างมีประสิทธิภาพ ...
# 21  พนักงานบริการได้มีการชี้แจงรายการซ่อม และอธิบา...
# 22  พนักงานบริการได้อธิบายการดูแลรักษารถเบื้องต้นท...
# 23  เมื่อพูดถึง ระยะเวลาที่ใช้ในการซ่อม ของศูนย์บร...
# 24             การประเมินเวลาที่ใช้ในการซ่อมแล้วเสร็จ
# 25  พนักงานบริการได้ติดต่อคุณในระหว่างวัน หรือได้ร...
# 26             พนักงานบริการซ่อมรถเสร็จตามเวลานัดหมาย
# 27               ระยะเวลาที่ใช้ในการซ่อมหรือรับบริการ
# 28  เมื่อพูดถึง การเข้าถึงช่องทางการแจ้งซ่อม ของศู...
# 29                     ช่องทางการแจ้งซ่อมสะดวกและง่าย
# 30  การสอบถามเพื่อเสนอความช่วยเหลือในการเข้ารับบริการ
# 31  เมื่อพูดถึง ราคาค่าซ่อม ของศูนย์บริการของบริษั...
# 32            การแจ้งประเมินราคาค่าซ่อมล่วงหน้าชัดเจน
# 33                        การบริการของพนักงานเก็บเงิน
# 34                        ความสุภาพของพนักงานเก็บเงิน
# 35  ขั้นตอนการชำระเงินเป็นไปอย่างรวดเร็วและเป็นมือ...
# 36                           ราคาค่าซ่อมมีความเหมาะสม

# %% [markdown]
# ### กลุ่มคำถามทั้งหมด

# %%
question_groups = list(filter(lambda x: type(x) == str, df_questions.group.unique()))
question_groups
# Out:
# ['group_53329680',
#  'group_53330038',
#  'group_53330117',
#  'group_53330290',
#  'group_53330322',
#  'group_53330394',
#  'group_53330407']

# %% [markdown]
# ### คะแนน "โดยรวมทุกสาขา" จากคำตอบของแต่ละกลุ่มคำถาม

# %%
for each_question_group in question_groups:
    print('--- ' + df_questions[df_questions['id'] == each_question_group]['question'].iloc[0] + ' ---')
    questions_in_group = df_questions[df_questions['group'] == each_question_group][['id', 'question']]
    for idx, question in zip(questions_in_group.id, questions_in_group.question):
        print(question + ': ' + str(df[idx].mean()))
    print()
# Out:
# --- กรุณาบอกหน่อยว่าการบริการหลังการขายของตัวแทนจำหน่ายหรือศูนย์บริการของบริษัท มาย มอเตอร ---
# การต้อนรับของพนักงาน เช่นเป็นกันเอง สุภาพ: 5.5
# ประสิทธิภาพในการซ่อม เช่น แก้ปัญหาได้ตรงจุดตั้งแต่การตรวจเช็คครั้งแรก: 7.0
# ความรู้และความสามารถของพนักงานในการแก้ไข และวิเคราะห์ปัญหา: 5.25
# ระยะเวลาที่ใช้ในการซ่อม: 5.5
# ราคาค่าซ่อมมีความเหมาะสม: 6.25
#
# --- เมื่อพูดถึงประสบการณในการเข้าใช้ศูนย์บริการของบริษัท มาย มอเตอร์ (ประเทศไทย) จำกัดครั้งนี ---
# สถานที่จอดรถลูกค้าเข้าใช้ศูนย์บริการ: 4.0
# พนักงานกล่าวสวัสดีเมื่อเข้าศูนย์บริการ: 3.5
# พนักงานสอบถามความต้องการใช้บริการ: 3.25
# มารยาทของพนักงาน: 3.25
# พนักงานมีความสุภาพ: 2.5
# พนักงานมีความเป็นกันเอง: 3.75
#
# --- เมื่อพูดถึง ประสิทธิภาพในการซ่อม ของศูนย์บริการของบริษัท มาย มอเตอร์ (ประเทศไทย) จำกัดครั ---
# พนักงานบริการอธิบายว่าได้ทำอะไรบ้าง ตามที่ระบุในใบงาน: 4.0
# พนักงานให้บริการครบถ้วนตามรายการสั่งซ่อม: 2.75
# แก้ปัญหาได้ตรงจุดตั้งแต่การตรวจเช็คครั้งแรก: 3.75
#
# --- เมื่อพูดถึง ความรู้และความสามารถของพนักงานในการแก้ไข และวิเคราะห์ปัญหา ของศูนย์บริการข ---
# รับฟังอย่างตั้งใจและจดรายละเอียดเกี่ยวกับสิ่งที่คุณเอ่ย: 3.75
# ตอบข้อซักถามและให้ข้อมูลได้อย่างมีประสิทธิภาพ ทันท่วงที: 3.0
# พนักงานบริการได้มีการชี้แจงรายการซ่อม และอธิบายรายละเอียดให้คุณทราบ: 3.5
# พนักงานบริการได้อธิบายการดูแลรักษารถเบื้องต้นที่เป็นประโยชน์: 3.0
#
# --- เมื่อพูดถึง ระยะเวลาที่ใช้ในการซ่อม ของศูนย์บริการของบริษัท มาย มอเตอร์ (ประเทศไทย) จำกัด ---
# การประเมินเวลาที่ใช้ในการซ่อมแล้วเสร็จ: 3.25
# พนักงานบริการได้ติดต่อคุณในระหว่างวัน หรือได้รับการแจ้งในระหว่างที่คุณรอรถซ่อม: 3.25
# พนักงานบริการซ่อมรถเสร็จตามเวลานัดหมาย: 3.0
# ระยะเวลาที่ใช้ในการซ่อมหรือรับบริการ: 2.5
#
# --- เมื่อพูดถึง การเข้าถึงช่องทางการแจ้งซ่อม ของศูนย์บริการของบริษัท มาย มอเตอร์ (ประเทศไทย)  ---
# ช่องทางการแจ้งซ่อมสะดวกและง่าย: 4.25
# การสอบถามเพื่อเสนอความช่วยเหลือในการเข้ารับบริการ: 3.25
#
# --- เมื่อพูดถึง ราคาค่าซ่อม ของศูนย์บริการของบริษัท มาย มอเตอร์ (ประเทศไทย) จำกัดครั้งนี้ คุณม ---
# การแจ้งประเมินราคาค่าซ่อมล่วงหน้าชัดเจน: 2.5
# การบริการของพนักงานเก็บเงิน: 3.75
# ความสุภาพของพนักงานเก็บเงิน: 2.75
# ขั้นตอนการชำระเงินเป็นไปอย่างรวดเร็วและเป็นมืออาชีพ: 3.25
# ราคาค่าซ่อมมีความเหมาะสม: 2.75

# %% [markdown]
# ### สาขาทั้งหมด

# %%
branch_column_name = 'list_53332714_choice'

# %%
branches = list(filter(lambda x: type(x) == str, df[branch_column_name].unique()))
branches
# Out:
# ['สาขา 2', 'สาขา 1']

# %% [markdown]
# ### คะแนน "แยกแต่ละสาขา" จากคำตอบของแต่ละกลุ่มคำถาม

# %%
for each_branch in branches:
    print('### ' + each_branch + ' ###')
    for each_question_group in question_groups:
        print('--- ' + df_questions[df_questions['id'] == each_question_group]['question'].iloc[0] + ' ---')
        questions_in_group = df_questions[df_questions['group'] == each_question_group][['id', 'question']]
        for idx, question in zip(questions_in_group.id, questions_in_group.question):
            print(question + ': ' + str(df[idx].mean()))
        print()
    print()
# Out:
# ### สาขา 2 ###
# --- กรุณาบอกหน่อยว่าการบริการหลังการขายของตัวแทนจำหน่ายหรือศูนย์บริการของบริษัท มาย มอเตอร ---
# การต้อนรับของพนักงาน เช่นเป็นกันเอง สุภาพ: 5.5
# ประสิทธิภาพในการซ่อม เช่น แก้ปัญหาได้ตรงจุดตั้งแต่การตรวจเช็คครั้งแรก: 7.0
# ความรู้และความสามารถของพนักงานในการแก้ไข และวิเคราะห์ปัญหา: 5.25
# ระยะเวลาที่ใช้ในการซ่อม: 5.5
# ราคาค่าซ่อมมีความเหมาะสม: 6.25
#
# --- เมื่อพูดถึงประสบการณในการเข้าใช้ศูนย์บริการของบริษัท มาย มอเตอร์ (ประเทศไทย) จำกัดครั้งนี ---
# สถานที่จอดรถลูกค้าเข้าใช้ศูนย์บริการ: 4.0
# พนักงานกล่าวสวัสดีเมื่อเข้าศูนย์บริการ: 3.5
# พนักงานสอบถามความต้องการใช้บริการ: 3.25
# มารยาทของพนักงาน: 3.25
# พนักงานมีความสุภาพ: 2.5
# พนักงานมีความเป็นกันเอง: 3.75
#
# --- เมื่อพูดถึง ประสิทธิภาพในการซ่อม ของศูนย์บริการของบริษัท มาย มอเตอร์ (ประเทศไทย) จำกัดครั ---
# พนักงานบริการอธิบายว่าได้ทำอะไรบ้าง ตามที่ระบุในใบงาน: 4.0
# พนักงานให้บริการครบถ้วนตามรายการสั่งซ่อม: 2.75
# แก้ปัญหาได้ตรงจุดตั้งแต่การตรวจเช็คครั้งแรก: 3.75
#
# --- เมื่อพูดถึง ความรู้และความสามารถของพนักงานในการแก้ไข และวิเคราะห์ปัญหา ของศูนย์บริการข ---
# รับฟังอย่างตั้งใจและจดรายละเอียดเกี่ยวกับสิ่งที่คุณเอ่ย: 3.75
# ตอบข้อซักถามและให้ข้อมูลได้อย่างมีประสิทธิภาพ ทันท่วงที: 3.0
# พนักงานบริการได้มีการชี้แจงรายการซ่อม และอธิบายรายละเอียดให้คุณทราบ: 3.5
# พนักงานบริการได้อธิบายการดูแลรักษารถเบื้องต้นที่เป็นประโยชน์: 3.0
#
# --- เมื่อพูดถึง ระยะเวลาที่ใช้ในการซ่อม ของศูนย์บริการของบริษัท มาย มอเตอร์ (ประเทศไทย) จำกัด ---
# การประเมินเวลาที่ใช้ในการซ่อมแล้วเสร็จ: 3.25
# พนักงานบริการได้ติดต่อคุณในระหว่างวัน หรือได้รับการแจ้งในระหว่างที่คุณรอรถซ่อม: 3.25
# พนักงานบริการซ่อมรถเสร็จตามเวลานัดหมาย: 3.0
# ระยะเวลาที่ใช้ในการซ่อมหรือรับบริการ: 2.5
#
# --- เมื่อพูดถึง การเข้าถึงช่องทางการแจ้งซ่อม ของศูนย์บริการของบริษัท มาย มอเตอร์ (ประเทศไทย)  ---
# ช่องทางการแจ้งซ่อมสะดวกและง่าย: 4.25
# การสอบถามเพื่อเสนอความช่วยเหลือในการเข้ารับบริการ: 3.25
#
# --- เมื่อพูดถึง ราคาค่าซ่อม ของศูนย์บริการของบริษัท มาย มอเตอร์ (ประเทศไทย) จำกัดครั้งนี้ คุณม ---
# การแจ้งประเมินราคาค่าซ่อมล่วงหน้าชัดเจน: 2.5
# การบริการของพนักงานเก็บเงิน: 3.75
# ความสุภาพของพนักงานเก็บเงิน: 2.75
# ขั้นตอนการชำระเงินเป็นไปอย่างรวดเร็วและเป็นมืออาชีพ: 3.25
# ราคาค่าซ่อมมีความเหมาะสม: 2.75
#
#
# ### สาขา 1 ###
# --- กรุณาบอกหน่อยว่าการบริการหลังการขายของตัวแทนจำหน่ายหรือศูนย์บริการของบริษัท มาย มอเตอร ---
# การต้อนรับของพนักงาน เช่นเป็นกันเอง สุภาพ: 5.5
# ประสิทธิภาพในการซ่อม เช่น แก้ปัญหาได้ตรงจุดตั้งแต่การตรวจเช็คครั้งแรก: 7.0
# ความรู้และความสามารถของพนักงานในการแก้ไข และวิเคราะห์ปัญหา: 5.25
# ระยะเวลาที่ใช้ในการซ่อม: 5.5
# ราคาค่าซ่อมมีความเหมาะสม: 6.25
#
# --- เมื่อพูดถึงประสบการณในการเข้าใช้ศูนย์บริการของบริษัท มาย มอเตอร์ (ประเทศไทย) จำกัดครั้งนี ---
# สถานที่จอดรถลูกค้าเข้าใช้ศูนย์บริการ: 4.0
# พนักงานกล่าวสวัสดีเมื่อเข้าศูนย์บริการ: 3.5
# พนักงานสอบถามความต้องการใช้บริการ: 3.25
# มารยาทของพนักงาน: 3.25
# พนักงานมีความสุภาพ: 2.5
# พนักงานมีความเป็นกันเอง: 3.75
#
# --- เมื่อพูดถึง ประสิทธิภาพในการซ่อม ของศูนย์บริการของบริษัท มาย มอเตอร์ (ประเทศไทย) จำกัดครั ---
# พนักงานบริการอธิบายว่าได้ทำอะไรบ้าง ตามที่ระบุในใบงาน: 4.0
# พนักงานให้บริการครบถ้วนตามรายการสั่งซ่อม: 2.75
# แก้ปัญหาได้ตรงจุดตั้งแต่การตรวจเช็คครั้งแรก: 3.75
#
# --- เมื่อพูดถึง ความรู้และความสามารถของพนักงานในการแก้ไข และวิเคราะห์ปัญหา ของศูนย์บริการข ---
# รับฟังอย่างตั้งใจและจดรายละเอียดเกี่ยวกับสิ่งที่คุณเอ่ย: 3.75
# ตอบข้อซักถามและให้ข้อมูลได้อย่างมีประสิทธิภาพ ทันท่วงที: 3.0
# พนักงานบริการได้มีการชี้แจงรายการซ่อม และอธิบายรายละเอียดให้คุณทราบ: 3.5
# พนักงานบริการได้อธิบายการดูแลรักษารถเบื้องต้นที่เป็นประโยชน์: 3.0
#
# --- เมื่อพูดถึง ระยะเวลาที่ใช้ในการซ่อม ของศูนย์บริการของบริษัท มาย มอเตอร์ (ประเทศไทย) จำกัด ---
# การประเมินเวลาที่ใช้ในการซ่อมแล้วเสร็จ: 3.25
# พนักงานบริการได้ติดต่อคุณในระหว่างวัน หรือได้รับการแจ้งในระหว่างที่คุณรอรถซ่อม: 3.25
# พนักงานบริการซ่อมรถเสร็จตามเวลานัดหมาย: 3.0
# ระยะเวลาที่ใช้ในการซ่อมหรือรับบริการ: 2.5
#
# --- เมื่อพูดถึง การเข้าถึงช่องทางการแจ้งซ่อม ของศูนย์บริการของบริษัท มาย มอเตอร์ (ประเทศไทย)  ---
# ช่องทางการแจ้งซ่อมสะดวกและง่าย: 4.25
# การสอบถามเพื่อเสนอความช่วยเหลือในการเข้ารับบริการ: 3.25
#
# --- เมื่อพูดถึง ราคาค่าซ่อม ของศูนย์บริการของบริษัท มาย มอเตอร์ (ประเทศไทย) จำกัดครั้งนี้ คุณม ---
# การแจ้งประเมินราคาค่าซ่อมล่วงหน้าชัดเจน: 2.5
# การบริการของพนักงานเก็บเงิน: 3.75
# ความสุภาพของพนักงานเก็บเงิน: 2.75
# ขั้นตอนการชำระเงินเป็นไปอย่างรวดเร็วและเป็นมืออาชีพ: 3.25
# ราคาค่าซ่อมมีความเหมาะสม: 2.75

# %% [markdown]
# ### [IGNORE] ทดลองโค้ดบางอย่าง

# %%
prefixes = ['list_', 'rating_', 'textfield_']
for each in questions:
    if any([each['id'].startswith(prefix) for prefix in prefixes]):
        try:
            print(df[each['id']])
        except KeyError:
            print('No one answers..')
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# 5        NaN
# 6        NaN
# 7        NaN
# 8        NaN
# 9        NaN
# 10    สาขา 2
# 11    สาขา 2
# 12    สาขา 1
# 13       NaN
# 14    สาขา 1
# Name: list_53332714_choice, dtype: object
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 7     NaN
# 8     NaN
# 9     NaN
# 10    4.0
# 11    4.0
# 12    7.0
# 13    NaN
# 14    7.0
# Name: rating_53329694, dtype: float64
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 7     NaN
# 8     NaN
# 9     NaN
# 10    8.0
# 11    5.0
# 12    8.0
# 13    NaN
# 14    7.0
# Name: rating_53329702, dtype: float64
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 7     NaN
# 8     NaN
# 9     NaN
# 10    5.0
# 11    7.0
# 12    2.0
# 13    NaN
# 14    7.0
# Name: rating_53329705, dtype: float64
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 7     NaN
# 8     NaN
# 9     NaN
# 10    9.0
# 11    2.0
# 12    4.0
# 13    NaN
# 14    7.0
# Name: rating_53329716, dtype: float64
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 7     NaN
# 8     NaN
# 9     NaN
# 10    6.0
# 11    3.0
# 12    9.0
# 13    NaN
# 14    7.0
# Name: rating_53329717, dtype: float64
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 7     NaN
# 8     NaN
# 9     NaN
# 10    3.0
# 11    4.0
# 12    5.0
# 13    NaN
# 14    4.0
# Name: rating_53175039, dtype: float64
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 7     NaN
# 8     NaN
# 9     NaN
# 10    4.0
# 11    3.0
# 12    5.0
# 13    NaN
# 14    2.0
# Name: rating_53175044, dtype: float64
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 7     NaN
# 8     NaN
# 9     NaN
# 10    3.0
# 11    4.0
# 12    2.0
# 13    NaN
# 14    4.0
# Name: rating_53175043, dtype: float64
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 7     NaN
# 8     NaN
# 9     NaN
# 10    2.0
# 11    5.0
# 12    3.0
# 13    NaN
# 14    3.0
# Name: rating_53175042, dtype: float64
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 7     NaN
# 8     NaN
# 9     NaN
# 10    3.0
# 11    2.0
# 12    2.0
# 13    NaN
# 14    3.0
# Name: rating_53175041, dtype: float64
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 7     NaN
# 8     NaN
# 9     NaN
# 10    4.0
# 11    2.0
# 12    4.0
# 13    NaN
# 14    5.0
# Name: rating_53175089, dtype: float64
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 7     NaN
# 8     NaN
# 9     NaN
# 10    5.0
# 11    1.0
# 12    5.0
# 13    NaN
# 14    5.0
# Name: rating_53175164, dtype: float64
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 7     NaN
# 8     NaN
# 9     NaN
# 10    1.0
# 11    3.0
# 12    2.0
# 13    NaN
# 14    5.0
# Name: rating_53175165, dtype: float64
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 7     NaN
# 8     NaN
# 9     NaN
# 10    2.0
# 11    4.0
# 12    4.0
# 13    NaN
# 14    5.0
# Name: rating_53175186, dtype: float64
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 7     NaN
# 8     NaN
# 9     NaN
# 10    3.0
# 11    5.0
# 12    2.0
# 13    NaN
# 14    5.0
# Name: rating_53175203, dtype: float64
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 7     NaN
# 8     NaN
# 9     NaN
# 10    4.0
# 11    1.0
# 12    3.0
# 13    NaN
# 14    4.0
# Name: rating_53175209, dtype: float64
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 7     NaN
# 8     NaN
# 9     NaN
# 10    3.0
# 11    2.0
# 12    5.0
# 13    NaN
# 14    4.0
# Name: rating_53175237, dtype: float64
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 7     NaN
# 8     NaN
# 9     NaN
# 10    4.0
# 11    3.0
# 12    1.0
# 13    NaN
# 14    4.0
# Name: rating_53175244, dtype: float64
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 7     NaN
# 8     NaN
# 9     NaN
# 10    2.0
# 11    5.0
# 12    2.0
# 13    NaN
# 14    4.0
# Name: rating_53175274, dtype: float64
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 7     NaN
# 8     NaN
# 9     NaN
# 10    5.0
# 11    2.0
# 12    2.0
# 13    NaN
# 14    4.0
# Name: rating_53175291, dtype: float64
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 7     NaN
# 8     NaN
# 9     NaN
# 10    1.0
# 11    4.0
# 12    3.0
# 13    NaN
# 14    4.0
# Name: rating_53175406, dtype: float64
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 7     NaN
# 8     NaN
# 9     NaN
# 10    2.0
# 11    1.0
# 12    3.0
# 13    NaN
# 14    4.0
# Name: rating_53175427, dtype: float64
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 7     NaN
# 8     NaN
# 9     NaN
# 10    4.0
# 11    5.0
# 12    4.0
# 13    NaN
# 14    4.0
# Name: rating_53175466, dtype: float64
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 7     NaN
# 8     NaN
# 9     NaN
# 10    3.0
# 11    1.0
# 12    5.0
# 13    NaN
# 14    4.0
# Name: rating_53175489, dtype: float64
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 7     NaN
# 8     NaN
# 9     NaN
# 10    2.0
# 11    2.0
# 12    2.0
# 13    NaN
# 14    4.0
# Name: rating_53175570, dtype: float64
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 7     NaN
# 8     NaN
# 9     NaN
# 10    4.0
# 11    4.0
# 12    3.0
# 13    NaN
# 14    4.0
# Name: rating_53175574, dtype: float64
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 7     NaN
# 8     NaN
# 9     NaN
# 10    2.0
# 11    2.0
# 12    3.0
# 13    NaN
# 14    4.0
# Name: rating_53175588, dtype: float64
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 7     NaN
# 8     NaN
# 9     NaN
# 10    4.0
# 11    1.0
# 12    4.0
# 13    NaN
# 14    4.0
# Name: rating_53175592, dtype: float64
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 7     NaN
# 8     NaN
# 9     NaN
# 10    1.0
# 11    4.0
# 12    2.0
# 13    NaN
# 14    4.0
# Name: rating_53175596, dtype: float64
